# %%
M1="BALTIMORE (AP) — The U.S. Coast Guard says it's looking for a man who has cost the service about $500,000 after responding to nearly 30 of his fake distress calls. In a press release published Friday, the Coast Guard says the 28 calls have originated from around the area of Annapolis, Maryland. Each call involved the same male voice and used an emergency radio channel.."

# %%
M2="The US Coast Guard says it's looking for a man who has cost the service about $500,000 after responding to nearly 30 of his fake distress calls, the AP reports. In a press release published Friday, the Coast Guard says the 28 calls have originated from around the area of Annapolis, Maryland. Each call involved the same male voice and used an emergency radio channel. He's been making the calls since July 2014. The two most recent calls were made on the night of July 21 and the early morning of July 22. The Coast Guard also says hoax calls distract rescuers from real emergencies, putting both the public and the responding crews at risk."

# %%
M3="BALTIMORE (AP) — The U.S. Coast Guard says it's looking for a man who has cost the service about $500,000 after responding to nearly 30 of his fake distress calls. The caller made 28 false distress alerts from Annapolis, Maryland, beginning in July 2014, according to the Coast Guard. The two most recent calls were made on the night of July 21 and the early morning of July 22.                                 The Coast Guard said in a press release Friday that the caller has been identified as a man in his 30s. He's been making the calls since July 2014. ンジ ンジ The caller is believed to be in his mid-30s and has lived in the area of Loretta Heights and Admiral Drive in Annapolis for the past two years. The caller's identity has not been released. =-=-=-=-=-=-=-=- =-=-=-=-=-=-=-=- The caller has not yet been arrested.   The estimated cost of the responses to these false alarms is $ 500,000. SourceFile                 Each call involved the same male voice and used an emergency radio channel.                 “A hoax call is a deadly and serious offense,” said Lt. Cmdr. Sara Wallace, who heads the response sector in Maryland. “Calls like these not only put our crews at risk, but they put the lives of the public at risk.”           Anyone with information about the caller is asked to contact the Coast Coast Guard's regional command center at 410-576-2525 or email investigators at CGIS-Baltimore@uscg.mil. ||||| A hoax caller"

# %%
reference="The US Coast Guard says it's looking for a man who has cost the service about $500,000 after responding to nearly 30 of his fake distress calls, reports the AP. In a press release published Friday, the Coast Guard says the 28 calls have originated from around the area of Annapolis, Maryland. Each call involved the same male voice and used an emergency radio channel. He's been making the calls since July 2014. The two most recent calls were made on the night of July 21 and the early morning of July 22. “A hoax call is a deadly and serious offense,” a Coast Guard rep tells NBC4, which notes that such calls are a felony that carry six years in prison, $10,000 civil fine, $250,000 criminal fine, and reimbursement to the Coast Guard. Calls like these not only put our crews at risk, but they put the lives of the public at risk."

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 4.7 MB 5.2 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 41.7 MB/s
# ...
#      |████████████████████████████████| 120 kB 52.2 MB/s
# ...

# %%
# !pip install git+https://github.com/huggingface/evaluate.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/huggingface/evaluate.git to /tmp/pip-req-build-iae4bla3
#   Running command git clone -q https://github.com/huggingface/evaluate.git /tmp/pip-req-build-iae4bla3
# ...
#      |████████████████████████████████| 365 kB 5.2 MB/s
# ...
#      |████████████████████████████████| 212 kB 57.9 MB/s
# ...
#      |████████████████████████████████| 115 kB 72.5 MB/s
# ...
#      |████████████████████████████████| 127 kB 43.4 MB/s
# ...
#   Created wheel for evaluate: filename=evaluate-0.2.3.dev0-py3-none-any.whl size=69982 sha256=4ba20c69e81be2029f15c32ee7de2f3bb518d6785384d3e083d7a1bb42a061ce
#   Stored in directory: /tmp/pip-ephem-wheel-cache-i26_z1wv/wheels/51/33/d9/f5852b34f6d2fe277fa150ba306fbf84a41907bcc783c9b09a
# Successfully built evaluate
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
# ...

# %%
#!python -c "import evaluate; print(evaluate.load('accuracy').compute(references=[1], predictions=[1]))"

# %%
import evaluate

# %%
#evaluate.list_evaluation_modules()

# %% [markdown]
# Rouge

# %%
# !pip install rouge_score
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24955 sha256=bae75712a8e00ecf196bb88cb76143a6d653e01f4e787ebbdbbe43915f2d9959
#   Stored in directory: /root/.cache/pip/wheels/84/ac/6b/38096e3c5bf1dc87911e3585875e21a3ac610348e740409c76
# Successfully built rouge-score
# ...

# %%
rouge = evaluate.load('rouge')

# %%
results_M6 = rouge.compute(predictions=[M1,M2,M3], references=[reference,reference,reference],rouge_types=['rouge1', 'rouge2','rouge3','rougeL'],use_aggregator=False,use_stemmer=True)
results_M6
# Out:
# {'rouge1': [0.5752212389380531, 0.7870036101083032, 0.6419753086419753],
#  'rouge2': [0.5357142857142857, 0.7127272727272728, 0.521091811414392],
#  'rouge3': [0.5225225225225224, 0.6666666666666666, 0.46384039900249374],
#  'rougeL': [0.5575221238938054, 0.7509025270758122, 0.41975308641975306]}

# %%
final_r1=results_M6['rouge1']

final_r1_results=[]
for i in range(3):
  tmp=final_r1[i]
  final_r1_results.append(round(tmp,4))

final_r1_results
# Out:
# [0.5752, 0.787, 0.642]

# %%
with open("/content/drive/MyDrive/Colab_Notebooks/Rouge/resultsmultidoc_r1_1.txt", 'w') as f:
  f.write(f'{final_r1_results}')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-cad6e8739a86> in <module>
# ----> 1 with open("/content/drive/MyDrive/Colab_Notebooks/Rouge/resultsLongT5_r1_1.txt", 'w') as f:
#       2   f.write(f'{final_r1_results}')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Colab_Notebooks/Rouge/resultsLongT5_r1_1.txt'

# %%
final_r2=results_M6['rouge2']

final_r2_results=[]
for i in range(3):
  tmp=final_r2[i]
  final_r2_results.append(round(tmp,4))

final_r2_results
# Out:
# [0.5357, 0.7127, 0.5211]

# %%
with open("/content/drive/MyDrive/Colab_Notebooks/Rouge/resultsmultidoc_r2_1.txt", 'w') as f:
  f.write(f'{final_r2_results}')

# %%
final_r3=results_M6['rouge3']

final_r3_results=[]
for i in range(3):
  tmp=final_r3[i]
  final_r3_results.append(round(tmp,4))

final_r3_results
# Out:
# [0.5225, 0.6667, 0.4638]

# %%
with open("/content/drive/MyDrive/Colab_Notebooks/Rouge/resultsmultidoc_r3_1.txt", 'w') as f:
  f.write(f'{final_r3_results}')

# %%
final_rL=results_M6['rougeL']

final_rL_results=[]
for i in range(3):
  tmp=final_rL[i]
  final_rL_results.append(round(tmp,4))

final_rL_results
# Out:
# [0.5575, 0.7509, 0.4198]

# %%
with open("/content/drive/MyDrive/Colab_Notebooks/Rouge/resultsmultidoc_rL1.txt", 'w') as f:
  f.write(f'{final_rL_results}')

# %%
with open("/content/drive/MyDrive/Colab_Notebooks/Rouge/resultsmultidoc_1.txt", 'w') as f:
  f.write(f'{results_M6}')

# %% [markdown]
# CHRF

# %%
# !pip install sacrebleu sacrebleu
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 116 kB 5.1 MB/s
# ...

# %%
results=[]

# %%
chrf = evaluate.load("chrf")
resultsc1 = chrf.compute(predictions=[M1], references=[reference],beta=1,word_order=0)
print(resultsc1)
results.append(resultsc1)
# Out:
# ...
# {'score': 57.8796403053279, 'char_order': 6, 'word_order': 0, 'beta': 1}

# %%
chrf = evaluate.load("chrf")
resultsc2 = chrf.compute(predictions=[M2], references=[reference],beta=1,word_order=0)
print(resultsc2)
results.append(resultsc2)
# Out:
# {'score': 75.65572755357407, 'char_order': 6, 'word_order': 0, 'beta': 1}

# %%
chrf = evaluate.load("chrf")
resultsc2 = chrf.compute(predictions=[M3], references=[reference],beta=1,word_order=0)
print(resultsc2)
results.append(resultsc2)
# Out:
# {'score': 57.537554993126015, 'char_order': 6, 'word_order': 0, 'beta': 1}

# %%
final_results=[]
for i in range(3):
  tmp=results[i]
 
  val=tmp["score"]/100
  final_results.append(round(val,4))



final_results
# Out:
# [0.5788, 0.7566, 0.5754]

# %%
with open("/content/drive/MyDrive/Colab_Notebooks/CHFR/resultsmultidoc_1.txt", 'w') as f:
  f.write(f'{final_results}')

# %% [markdown]
# Meteor

# %%
meteor = evaluate.load('meteor')
# Out:
# ...
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...

# %%
meteor_results=[]

# %%
results = meteor.compute(predictions=[M1], references=[reference])
meteor_results.append(round(results['meteor'], 4))

meteor_results
# Out:
# [0.3563]

# %%
results = meteor.compute(predictions=[M2], references=[reference])
meteor_results.append(round(results['meteor'], 4))

meteor_results
# Out:
# [0.3563, 0.6366]

# %%
results = meteor.compute(predictions=[M3], references=[reference])
meteor_results.append(round(results['meteor'], 4))

meteor_results
# Out:
# [0.3563, 0.6366, 0.5975]

# %%
with open("/content/drive/MyDrive/Colab_Notebooks/Meteor/resultsmultidoc_1.txt", 'w') as f:
  f.write(f'{meteor_results}')

# %% [markdown]
# Bert Score

# %%
# !pip install bert_score
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 60 kB 3.3 MB/s
# ...

# %%
bertscore = evaluate.load("bertscore")

# %%
results_bt = bertscore.compute(predictions=[M1,M2,M3], references=[reference,reference,reference],lang="en")

# %%
results_bt
# Out:
# {'precision': [0.962206244468689, 0.9758557677268982, 0.8170945644378662],
#  'recall': [0.8874062895774841, 0.9333078265190125, 0.9199153780937195],
#  'f1': [0.9232938289642334, 0.9541076421737671, 0.8654617071151733],
#  'hashcode': 'roberta-large_L17_no-idf_version=0.3.11(hug_trans=4.21.3)'}

# %%
final_bertscore=results_bt['f1']
final_bertscore
final_bt_results=[]
for i in range(3):
  tmp=final_bertscore[i]
  final_bt_results.append(round(tmp,4))

# %%
final_bt_results
# Out:
# [0.9233, 0.9541, 0.8655]

# %%
with open("/content/drive/MyDrive/Colab_Notebooks/BertScore/resultsmultidoc_1.txt", 'w') as f:
  f.write(f'{final_bt_results}')
