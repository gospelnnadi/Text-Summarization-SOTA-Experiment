# %%
M6_path="/content/drive/MyDrive/Colab_Notebooks/LongT5/Model6/summary2.txt"
M7_path="/content/drive/MyDrive/Colab_Notebooks/LongT5/Model7/summary2.txt"
ref_path="/content/drive/MyDrive/Colab_Notebooks/Longformer/Reference2.txt"

# %%
with open(M6_path, 'r') as f:
  M6=f.read()

# %%
with open(M7_path, 'r') as f:
  M7=f.read()

# %%
with open(ref_path, 'r') as f:
    reference=f.read()

# %%
f.close()

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 4.7 MB 30.3 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 58.4 MB/s
# ...
#      |████████████████████████████████| 120 kB 27.8 MB/s
# ...

# %%
# !pip install git+https://github.com/huggingface/evaluate.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/huggingface/evaluate.git to /tmp/pip-req-build-71_tdom1
#   Running command git clone -q https://github.com/huggingface/evaluate.git /tmp/pip-req-build-71_tdom1
# ...
#      |████████████████████████████████| 365 kB 26.6 MB/s
# ...
#      |████████████████████████████████| 212 kB 72.6 MB/s
# ...
#      |████████████████████████████████| 115 kB 72.3 MB/s
# ...
#      |████████████████████████████████| 127 kB 67.2 MB/s
# ...
#   Created wheel for evaluate: filename=evaluate-0.2.3.dev0-py3-none-any.whl size=69982 sha256=6afde2bf3a4fe341e7f1e21a298dc964f4de0f367c2750acaeb4daab661d9c4c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-0hmv243l/wheels/51/33/d9/f5852b34f6d2fe277fa150ba306fbf84a41907bcc783c9b09a
# Successfully built evaluate
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
# ...

# %%
#!python -c "import evaluate; print(evaluate.load('accuracy').compute(references=[1], predictions=[1]))"

# %%
import evaluate

# %%
#evaluate.list_evaluation_modules()

# %% [markdown]
# Rouge

# %%
# !pip install rouge_score
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24955 sha256=bfee42c1159b292b0452ff7d3dcc49bda100eb66a7b4eebf1039bc364d22bb76
#   Stored in directory: /root/.cache/pip/wheels/84/ac/6b/38096e3c5bf1dc87911e3585875e21a3ac610348e740409c76
# Successfully built rouge-score
# ...

# %%
rouge = evaluate.load('rouge')

# %%
results_M1 = rouge.compute(predictions=[M6,M7], references=[reference,reference],rouge_types=['rouge1', 'rouge2','rouge3','rougeL'],use_aggregator=False,use_stemmer=True)
results_M1
# Out:
# {'rouge1': [0.3964497041420118, 0.484375],
#  'rouge2': [0.09523809523809523, 0.19607843137254902],
#  'rouge3': [0.011976047904191617, 0.1062992125984252],
#  'rougeL': [0.1834319526627219, 0.28125000000000006]}

# %%
final_r1=results_M1['rouge1']

final_r1_results=[]
for i in range(2):
  tmp=final_r1[i]
  final_r1_results.append(round(tmp,4))

final_r1_results
# Out:
# [0.3964, 0.4844]

# %%
with open("/content/drive/MyDrive/Colab_Notebooks/Rouge/resultsLongT5_r1_2.txt", 'w') as f:
  f.write(f'{final_r1_results}')

# %%
final_r2=results_M1['rouge2']

final_r2_results=[]
for i in range(2):
  tmp=final_r2[i]
  final_r2_results.append(round(tmp,4))

final_r2_results
# Out:
# [0.0952, 0.1961]

# %%
with open("/content/drive/MyDrive/Colab_Notebooks/Rouge/resultsLongT5_r2_2.txt", 'w') as f:
  f.write(f'{final_r2_results}')

# %%
final_r3=results_M1['rouge3']

final_r3_results=[]
for i in range(2):
  tmp=final_r3[i]
  final_r3_results.append(round(tmp,4))

final_r3_results
# Out:
# [0.012, 0.1063]

# %%
with open("/content/drive/MyDrive/Colab_Notebooks/Rouge/resultsLongT5_r3_2.txt", 'w') as f:
  f.write(f'{final_r3_results}')

# %%
final_rL=results_M1['rougeL']

final_rL_results=[]
for i in range(2):
  tmp=final_rL[i]
  final_rL_results.append(round(tmp,4))

final_rL_results
# Out:
# [0.1834, 0.2813]

# %%
with open("/content/drive/MyDrive/Colab_Notebooks/Rouge/resultsLongT5_rL2.txt", 'w') as f:
  f.write(f'{final_rL_results}')

# %%
with open("/content/drive/MyDrive/Colab_Notebooks/Rouge/resultsLongT5_2.txt", 'w') as f:
  f.write(f'{results_M1}')

# %% [markdown]
# CHRF

# %%
# !pip install sacrebleu sacrebleu
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 116 kB 28.7 MB/s
# ...

# %%
results=[]

# %%
chrf = evaluate.load("chrf")
resultsc1 = chrf.compute(predictions=[M6], references=[reference],beta=1,word_order=0)
print(resultsc1)
results.append(resultsc1)
# Out:
# ...
# {'score': 32.02752296485058, 'char_order': 6, 'word_order': 0, 'beta': 1}

# %%
chrf = evaluate.load("chrf")
resultsc2 = chrf.compute(predictions=[M7], references=[reference],beta=1,word_order=0)
print(resultsc2)
results.append(resultsc2)
# Out:
# {'score': 48.456151139583454, 'char_order': 6, 'word_order': 0, 'beta': 1}

# %%
final_results=[]
for i in range(2):
  tmp=results[i]
 
  val=tmp["score"]/100
  final_results.append(round(val,4))



final_results
# Out:
# [0.3203, 0.4846]

# %%
with open("/content/drive/MyDrive/Colab_Notebooks/CHFR/resultsLongT5_2.txt", 'w') as f:
  f.write(f'{final_results}')

# %% [markdown]
# Meteor

# %%
meteor = evaluate.load('meteor')
# Out:
# ...
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...

# %%
meteor_results=[]

# %%
results = meteor.compute(predictions=[M6], references=[reference])
meteor_results.append(round(results['meteor'], 4))

meteor_results
# Out:
# [0.1902]

# %%
results = meteor.compute(predictions=[M7], references=[reference])
meteor_results.append(round(results['meteor'], 4))

meteor_results
# Out:
# [0.1902, 0.3587]

# %%
with open("/content/drive/MyDrive/Colab_Notebooks/Meteor/resultsLongT5_2.txt", 'w') as f:
  f.write(f'{meteor_results}')

# %% [markdown]
# Bert Score

# %%
# !pip install bert_score
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 60 kB 182 kB/s
# ...

# %%
bertscore = evaluate.load("bertscore")

# %%
results_bt = bertscore.compute(predictions=[M6,M7], references=[reference,reference],lang="en")

# %%
results_bt
# Out:
# {'precision': [0.8650654554367065, 0.8483033180236816],
#  'recall': [0.8196827173233032, 0.8695300221443176],
#  'f1': [0.8417628407478333, 0.8587855100631714],
#  'hashcode': 'roberta-large_L17_no-idf_version=0.3.11(hug_trans=4.21.3)'}

# %%
final_bertscore=results_bt['f1']
final_bertscore
final_bt_results=[]
for i in range(2):
  tmp=final_bertscore[i]
  final_bt_results.append(round(tmp,4))

# %%
final_bt_results
# Out:
# [0.8418, 0.8588]

# %%
with open("/content/drive/MyDrive/Colab_Notebooks/BertScore/resultsLongT5_2.txt", 'w') as f:
  f.write(f'{final_bt_results}')
