# %%
M1_path="/content/drive/MyDrive/Colab_Notebooks/Bart/Pt/cnn/summary6.txt"
M2_path="/content/drive/MyDrive/Colab_Notebooks/Bart/Pt/distilAMARV/summary6.txt"
M3_path= "/content/drive/MyDrive/Colab_Notebooks/Bart/TF/xsum/summary6.txt"
M4_path= "/content/drive/MyDrive/Colab_Notebooks/Pegasus/py_cnn/summary6.txt"
M5_path= "/content/drive/MyDrive/Colab_Notebooks/Pegasus/py-xsum/summary6.txt"
M6_path= "/content/drive/MyDrive/Colab_Notebooks/Pegasus/py-pegasus-large/summary6.txt"
M7_path= "/content/drive/MyDrive/Colab_Notebooks/Pegasus/tf_pegasus-large/summary6.txt"
M8_path= "/content/drive/MyDrive/Colab_Notebooks/Pegasus/tf_x-sum/summary6.txt"
M9_path= "/content/drive/MyDrive/Colab_Notebooks/Bart/Pt/distilMultiNews/summary6.txt"
ref_path="/content/drive/MyDrive/Colab_Notebooks/reference6.txt"

# %%
with open(M1_path, 'r') as f:
  M1=f.read()
  print(M1)
# Out:
# Part E of title XVIII of the Social Security Act is amended by inserting after section 1866E the following new section: SEC. 1866F. The pilot program shall be conducted for a period of 3 years consistent with the following: (A) Selection of area. (B) Card reader technology.

# %%
with open(M2_path, 'r') as f:
  M2=f.read()

# %%
with open(M3_path, 'r') as f:
  M3=f.read()

# %%
with open(M4_path, 'r') as f:
  M4=f.read()

# %%
with open(M5_path, 'r') as f:
  M5=f.read()

# %%
with open(M6_path, 'r') as f:
  M6=f.read()

# %%
with open(M7_path, 'r') as f:
  M7=f.read()

# %%
with open(M8_path, 'r') as f:
    M8=f.read()

# %%
with open(M9_path, 'r') as f:
  M9=f.read()

# %%
with open(ref_path, 'r') as f:
    reference=f.read()

# %%
f.close()

# %%
# !pip install git+https://github.com/huggingface/evaluate.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/huggingface/evaluate.git to /tmp/pip-req-build-4fzzhz7f
#   Running command git clone -q https://github.com/huggingface/evaluate.git /tmp/pip-req-build-4fzzhz7f
# ...

# %%
#!python -c "import evaluate; print(evaluate.load('accuracy').compute(references=[1], predictions=[1]))"

# %%
import evaluate

# %%
#evaluate.list_evaluation_modules()

# %% [markdown]
# Rouge

# %%
# !pip install rouge_score
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
rouge = evaluate.load('rouge')

# %%
predictions = ["ter is no child looking asian here"]
references = ["there was a child from asia"]
results = rouge.compute(predictions=predictions, references=references ,use_aggregator=False,use_stemmer=True)
results
# Out:
# {'rouge1': [0.15384615384615383],
#  'rouge2': [0.0],
#  'rougeL': [0.15384615384615383],
#  'rougeLsum': [0.15384615384615383]}

# %%
results_M1 = rouge.compute(predictions=[M1,M2,M3,M4,M5,M6,M7,M8,M9], references=[reference,reference,reference,reference,reference,reference,reference,reference,reference],rouge_types=['rouge1', 'rouge2','rouge3','rougeL','rougeLsum'],use_aggregator=False,use_stemmer=True)
results_M1
# Out:
# {'rouge1': [0.21719457013574664,
#   0.25120772946859904,
#   0.08510638297872342,
#   0.3557312252964427,
#   0.09574468085106383,
#   0.31297709923664124,
#   0.41638225255972694,
#   0.05405405405405405,
#   0.3591549295774647],
#  'rouge2': [0.0365296803652968,
#   0.07804878048780488,
#   0.03225806451612903,
#   0.10358565737051793,
#   0.06451612903225806,
#   0.08461538461538462,
#   0.07560137457044673,
#   0.0,
#   0.14184397163120568],
#  'rouge3': [0.018433179723502308,
#   0.04926108374384237,
#   0.010869565217391306,
#   0.0642570281124498,
#   0.05434782608695652,
#   0.054263565891472874,
#   0.020761245674740487,
#   0.0,
#   0.09285714285714286],
#  'rougeL': [0.11764705882352942,
#   0.17391304347826086,
#   0.06382978723404255,
#   0.22134387351778653,
#   0.07446808510638298,
#   0.17557251908396945,
#   0.23208191126279865,
#   0.04324324324324325,
#   0.2323943661971831],
#  'rougeLsum': [0.11764705882352942,
#   0.17391304347826086,
#   0.06382978723404255,
# ...

# %%
print(M2)
# Out:
# This Act may be cited as the Medicare Common Access Card Act of 2017” SEC. 2. MEDICARE SMART CARD PILOT PROGRAM. (a) Implementation. (1) In general. ... ... ... the ... ... of ... the Department of Health and ...

# %%
print(results_M1)
# Out:
# {'rouge1': [0.21719457013574664, 0.25120772946859904, 0.08510638297872342, 0.3557312252964427, 0.09574468085106383, 0.31297709923664124, 0.41638225255972694, 0.05405405405405405, 0.3591549295774647], 'rouge2': [0.0365296803652968, 0.07804878048780488, 0.03225806451612903, 0.10358565737051793, 0.06451612903225806, 0.08461538461538462, 0.07560137457044673, 0.0, 0.14184397163120568], 'rouge3': [0.018433179723502308, 0.04926108374384237, 0.010869565217391306, 0.0642570281124498, 0.05434782608695652, 0.054263565891472874, 0.020761245674740487, 0.0, 0.09285714285714286], 'rougeL': [0.11764705882352942, 0.17391304347826086, 0.06382978723404255, 0.22134387351778653, 0.07446808510638298, 0.17557251908396945, 0.23208191126279865, 0.04324324324324325, 0.2323943661971831], 'rougeLsum': [0.11764705882352942, 0.17391304347826086, 0.06382978723404255, 0.22134387351778653, 0.07446808510638298, 0.17557251908396945, 0.23208191126279865, 0.04324324324324325, 0.2323943661971831]}

# %%
final_r1=results_M1['rouge1']

final_r1_results=[]
for i in range(9):
  tmp=final_r1[i]
  final_r1_results.append(round(tmp,4))

final_r1_results
# Out:
# [0.2172, 0.2512, 0.0851, 0.3557, 0.0957, 0.313, 0.4164, 0.0541, 0.3592]

# %%
with open("/content/drive/MyDrive/Colab_Notebooks/Rouge/resultsr1_6.txt", 'w') as f:
  f.write(f'{final_r1_results}')

# %%
final_r2=results_M1['rouge2']

final_r2_results=[]
for i in range(9):
  tmp=final_r2[i]
  final_r2_results.append(round(tmp,4))

final_r2_results
# Out:
# [0.0365, 0.078, 0.0323, 0.1036, 0.0645, 0.0846, 0.0756, 0.0, 0.1418]

# %%
with open("/content/drive/MyDrive/Colab_Notebooks/Rouge/resultsr2_6.txt", 'w') as f:
  f.write(f'{final_r2_results}')

# %%
final_r3=results_M1['rouge3']

final_r3_results=[]
for i in range(9):
  tmp=final_r3[i]
  final_r3_results.append(round(tmp,4))

final_r3_results
# Out:
# [0.0184, 0.0493, 0.0109, 0.0643, 0.0543, 0.0543, 0.0208, 0.0, 0.0929]

# %%
with open("/content/drive/MyDrive/Colab_Notebooks/Rouge/resultsr3_6.txt", 'w') as f:
  f.write(f'{final_r3_results}')

# %%
final_rL=results_M1['rougeL']

final_rL_results=[]
for i in range(9):
  tmp=final_rL[i]
  final_rL_results.append(round(tmp,4))

final_rL_results
# Out:
# [0.1176, 0.1739, 0.0638, 0.2213, 0.0745, 0.1756, 0.2321, 0.0432, 0.2324]

# %%
with open("/content/drive/MyDrive/Colab_Notebooks/Rouge/resultsrL6.txt", 'w') as f:
  f.write(f'{final_rL_results}')

# %%
with open("/content/drive/MyDrive/Colab_Notebooks/Rouge/result6.txt", 'w') as f:
  f.write(f'{results_M1}')

# %% [markdown]
# CHRF

# %%
# !pip install sacrebleu sacrebleu
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
results=[]

# %%
chrf = evaluate.load("chrf")
resultsc1 = chrf.compute(predictions=[M1], references=[reference],beta=1,word_order=0)
print(resultsc1)
results.append(resultsc1)
# Out:
# {'score': 16.442221963820362, 'char_order': 6, 'word_order': 0, 'beta': 1}

# %%
chrf = evaluate.load("chrf")
resultsc2 = chrf.compute(predictions=[M2], references=[reference],beta=1,word_order=0)
print(resultsc2)
results.append(resultsc2)
# Out:
# {'score': 12.123150628132464, 'char_order': 6, 'word_order': 0, 'beta': 1}

# %%
chrf = evaluate.load("chrf")
resultsc3 = chrf.compute(predictions=[M3], references=[reference],beta=1,word_order=0)
print(resultsc3)
results.append(resultsc3)
# Out:
# {'score': 6.252128089201389, 'char_order': 6, 'word_order': 0, 'beta': 1}

# %%
chrf = evaluate.load("chrf")
resultsc4 = chrf.compute(predictions=[M4], references=[reference],beta=1,word_order=0)
print(resultsc4)
results.append(resultsc4)
# Out:
# {'score': 28.005592698015224, 'char_order': 6, 'word_order': 0, 'beta': 1}

# %%
chrf = evaluate.load("chrf")
resultsc5 = chrf.compute(predictions=[M5], references=[reference],beta=1,word_order=0)
print(resultsc5)
results.append(resultsc5)
# Out:
# {'score': 8.865510780199887, 'char_order': 6, 'word_order': 0, 'beta': 1}

# %%
chrf = evaluate.load("chrf")
resultsc6 = chrf.compute(predictions=[M6], references=[reference],beta=1,word_order=0)
print(resultsc6)
results.append(resultsc6)
# Out:
# {'score': 29.957739822783918, 'char_order': 6, 'word_order': 0, 'beta': 1}

# %%
chrf = evaluate.load("chrf")
resultsc7 = chrf.compute(predictions=[M7], references=[reference],beta=1,word_order=0)
print(resultsc7)
results.append(resultsc7)
# Out:
# {'score': 31.961054290480945, 'char_order': 6, 'word_order': 0, 'beta': 1}

# %%
chrf = evaluate.load("chrf")
resultsc8 = chrf.compute(predictions=[M8], references=[reference],beta=1,word_order=0)
print(resultsc8)
results.append(resultsc8)
# Out:
# {'score': 3.2558786608349886, 'char_order': 6, 'word_order': 0, 'beta': 1}

# %%
chrf = evaluate.load("chrf")
resultsc8 = chrf.compute(predictions=[M9], references=[reference],beta=1,word_order=0)
print(resultsc8)
results.append(resultsc8)
# Out:
# {'score': 35.00820129682115, 'char_order': 6, 'word_order': 0, 'beta': 1}

# %%
final_results=[]
for i in range(9):
  tmp=results[i]
 
  val=tmp["score"]/100
  final_results.append(round(val,4))



final_results
# Out:
# [0.1644, 0.1212, 0.0625, 0.2801, 0.0887, 0.2996, 0.3196, 0.0326, 0.3501]

# %%
with open("/content/drive/MyDrive/Colab_Notebooks/CHFR/results6.txt", 'w') as f:
  f.write(f'{final_results}')

# %% [markdown]
# Meteor

# %%
meteor = evaluate.load('meteor')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
meteor_results=[]

# %%
results = meteor.compute(predictions=[M1], references=[reference])
meteor_results.append(round(results['meteor'], 4))

meteor_results
# Out:
# [0.0837]

# %%
results = meteor.compute(predictions=[M2], references=[reference])
meteor_results.append(round(results['meteor'], 4))

meteor_results
# Out:
# [0.0837, 0.0893]

# %%
results = meteor.compute(predictions=[M3], references=[reference])
meteor_results.append(round(results['meteor'], 4))

meteor_results
# Out:
# [0.0837, 0.0893, 0.0214]

# %%
results = meteor.compute(predictions=[M4], references=[reference])
meteor_results.append(round(results['meteor'], 4))

meteor_results
# Out:
# [0.0837, 0.0893, 0.0214, 0.1285]

# %%
results = meteor.compute(predictions=[M5], references=[reference])
meteor_results.append(round(results['meteor'], 4))

meteor_results
# Out:
# [0.0837, 0.0893, 0.0214, 0.1285, 0.034]

# %%
results = meteor.compute(predictions=[M6], references=[reference])
meteor_results.append(round(results['meteor'], 4))

meteor_results
# Out:
# [0.0837, 0.0893, 0.0214, 0.1285, 0.034, 0.1306]

# %%
results = meteor.compute(predictions=[M7], references=[reference])
meteor_results.append(round(results['meteor'], 4))

meteor_results
# Out:
# [0.0837, 0.0893, 0.0214, 0.1285, 0.034, 0.1306, 0.1764]

# %%
results = meteor.compute(predictions=[M8], references=[reference])
meteor_results.append(round(results['meteor'], 4))

meteor_results
# Out:
# [0.0837, 0.0893, 0.0214, 0.1285, 0.034, 0.1306, 0.1764, 0.0188]

# %%
results = meteor.compute(predictions=[M9], references=[reference])
meteor_results.append(round(results['meteor'], 4))

meteor_results
# Out:
# [0.0837, 0.0893, 0.0214, 0.1285, 0.034, 0.1306, 0.1764, 0.0188, 0.1418]

# %%
with open("/content/drive/MyDrive/Colab_Notebooks/Meteor/results6.txt", 'w') as f:
  f.write(f'{meteor_results}')

# %% [markdown]
# Bert Score

# %%
# !pip install bert_score
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
bertscore = evaluate.load("bertscore")

# %%
results_bt = bertscore.compute(predictions=[M1,M2,M3,M4,M5,M6,M7,M8,M9], references=[reference,reference,reference,reference,reference,reference,reference,reference,reference],lang="en")

# %%
results_bt
# Out:
# {'f1': [0.819314181804657,
#   0.8094920516014099,
#   0.8307899832725525,
#   0.8290241360664368,
#   0.8348420858383179,
#   0.8160362839698792,
#   0.8209302425384521,
#   0.8129579424858093,
#   0.826988160610199],
#  'hashcode': 'roberta-large_L17_no-idf_version=0.3.11(hug_trans=4.21.0)',
#  'precision': [0.8332723379135132,
#   0.8298326730728149,
#   0.8834887146949768,
#   0.8371873497962952,
#   0.8954967856407166,
#   0.836383581161499,
#   0.8315266370773315,
#   0.8602030873298645,
#   0.8491179347038269],
#  'recall': [0.8058160543441772,
#   0.790124773979187,
#   0.7840241193771362,
#   0.8210184574127197,
#   0.7818828225135803,
#   0.796655535697937,
#   0.8106005191802979,
#   0.770632266998291,
#   0.8059825897216797]}

# %%
final_bertscore=results_bt['f1']
final_bertscore
final_bt_results=[]
for i in range(9):
  tmp=final_bertscore[i]
  final_bt_results.append(round(tmp,4))

# %%
final_bt_results
# Out:
# [0.8193, 0.8095, 0.8308, 0.829, 0.8348, 0.816, 0.8209, 0.813, 0.827]

# %%
with open("/content/drive/MyDrive/Colab_Notebooks/BertScore/results6.txt", 'w') as f:
  f.write(f'{final_bt_results}')
