# %%
# %cd /content/drive/MyDrive/Colab_Notebooks/REFLECT
# Out:
# /content/drive/MyDrive/Colab_Notebooks/REFLECT

# %%
# !git clone https://github.com/yunzhusong/NAACL2022-REFLECT.git
# Out:
# Cloning into 'NAACL2022-REFLECT'...
# remote: Enumerating objects: 173, done.
# remote: Counting objects: 100% (173/173), done.
# remote: Compressing objects: 100% (141/141), done.
# remote: Total 173 (delta 81), reused 93 (delta 31), pack-reused 0
# Receiving objects: 100% (173/173), 88.56 KiB | 2.53 MiB/s, done.
# Resolving deltas: 100% (81/81), done.

# %%
# %cd NAACL2022-REFLECT/
# Out:
# /content/drive/MyDrive/Colab_Notebooks/REFLECT/NAACL2022-REFLECT

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 131 kB 7.2 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 50.8 MB/s
# ...
#      |████████████████████████████████| 53 kB 2.2 MB/s
# ...
#      |████████████████████████████████| 149 kB 70.5 MB/s
# ...
#      |████████████████████████████████| 178 kB 69.0 MB/s
# ...
#      |████████████████████████████████| 97 kB 8.3 MB/s
# ...
#      |████████████████████████████████| 287 kB 70.3 MB/s
# ...
#      |████████████████████████████████| 86 kB 7.1 MB/s
# ...
#      |████████████████████████████████| 125 kB 62.2 MB/s
# ...
#      |████████████████████████████████| 3.9 MB 45.6 MB/s
# ...
#      |████████████████████████████████| 56 kB 5.1 MB/s
# ...
#      |████████████████████████████████| 61 kB 9.5 MB/s
# ...
#      |████████████████████████████████| 97 kB 8.3 MB/s
# ...
#      |████████████████████████████████| 160 kB 71.2 MB/s
# ...
#      |████████████████████████████████| 112 kB 64.3 MB/s
# ...

# %%
# !tar -xvf /content/drive/MyDrive/Colab_Notebooks/REFLECT/NAACL2022-REFLECT/final.tar.gz
# Out:
# final/
# final/checkpoint-3200/
# final/checkpoint-3200/trainer_state.json
# final/checkpoint-3200/training_args.bin
# final/checkpoint-3200/model_args.bin
# final/checkpoint-3200/test_results.json
# final/checkpoint-3200/test_extractions.csv
# final/checkpoint-3200/config.json
# final/checkpoint-3200/pytorch_model.bin
# final/checkpoint-3200/test_generations.csv
# final/checkpoint-3200/vocab.json
# final/checkpoint-3200/pred.json
# final/checkpoint-3200/optimizer.pt
# final/checkpoint-3200/special_tokens_map.json
# final/checkpoint-3200/all_results.json
# final/checkpoint-3200/scheduler.pt
# final/checkpoint-3200/tokenizer_config.json
# final/checkpoint-3200/data_args.bin
# final/checkpoint-3200/merges.txt
# final/checkpoint-3200/eval.json

# %%
# %cd src
# Out:
# /content/drive/MyDrive/Colab_Notebooks/REFLECT/NAACL2022-REFLECT/src

# %%
# !tar -xvf /content/drive/MyDrive/Colab_Notebooks/REFLECT/NAACL2022-REFLECT/src/datasets/ext_oracle/multi_news_bl_own.tar.gz
# Out:
# ._multi_news_bl_own
# multi_news_bl_own/
# multi_news_bl_own/._validation.csv
# multi_news_bl_own/validation.csv
# multi_news_bl_own/._test.csv
# multi_news_bl_own/test.csv
# multi_news_bl_own/._train.csv
# multi_news_bl_own/train.csv

# %%
# !tar -xvf /content/drive/MyDrive/Colab_Notebooks/REFLECT/NAACL2022-REFLECT/src/datasets/ext_oracle/xscience_bl_own.tar.gz

# %%
# !python main.py /content/drive/MyDrive/Colab_Notebooks/REFLECT/NAACL2022-REFLECT/src/eval_.json
# Out:
# INFO: Pandarallel will run on 2 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Error loading corpus: Package 'corpus' not found in index
# Task type: seq2seq
# WARNING:__main__:Process rank: -1, device: cuda:0, n_gpu: 1, distributed training: False, 16-bits training: False
# WARNING:__main__:Load the specified trained model
# ...

# %%
# !pip install transformers
# !pip install -U huggingface_hub
# !pip install datasets
# !pip install -U evaluate

# !pip install rouge_score

import datasets
from datasets import load_dataset
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd

df_ref = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/MultiNews/test10document.csv')
df_sum = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/REFLECT/NAACL2022-REFLECT/outputs/multi_news/test_generations.csv')

# %%
#ref=df_ref['summary'][2]
ref=''.join(map(str,df_ref['summary'][2]))

# %%
#summ= df_sum['summary_gen'][2]
summ=''.join(map(str,df_sum['summary_gen'][2]))

# %%
import evaluate
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-44-5bbdaa20d86c> in <module>
# ----> 1 import evaluate
#
# /usr/local/lib/python3.7/dist-packages/evaluate/__init__.py in <module>
#      27 del version
#      28
# ---> 29 from .evaluator import (
#      30     Evaluator,
#      31     ImageClassificationEvaluator,
#
# /usr/local/lib/python3.7/dist-packages/evaluate/evaluator/__init__.py in <module>
#      25 from typing import Dict, List
#      26
# ---> 27 from .base import Evaluator
#      28 from .image_classification import ImageClassificationEvaluator
#      29 from .question_answering import QuestionAnsweringEvaluator
#
# /usr/local/lib/python3.7/dist-packages/evaluate/evaluator/base.py in <module>
#      43 from typing_extensions import Literal
#      44
# ---> 45 from ..loading import load
#      46 from ..module import EvaluationModule
# ...

# %%
# !python -c "import evaluate; print(evaluate.load('exact_match').compute(references=['hello'],predictions=['hello']))"
# Out:
# ...
# {'exact_match': 1.0}

# %%
rouge = load_metric("rouge")

# %%
#rouge = evaluate.load("rouge")
score = rouge.compute(predictions=summ, references=ref,rouge_types=['rouge1', 'rouge2','rouge3','rougeL'],use_aggregator=False,use_stemmer=True)
#print(score['rouge1'].mid)
#print(score['rouge2'].mid)
#print(score['rouge3'].mid)
#print(score['rougeL'].mid)
score
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-ff73cfecf452> in <module>
#       1 #rouge = evaluate.load("rouge")
# ----> 2 score = rouge.compute(predictions=summ, references=ref,rouge_types=['rouge1', 'rouge2','rouge3','rougeL'],use_aggregator=False,use_stemmer=True)
#       3 #print(score['rouge1'].mid)
#       4 #print(score['rouge2'].mid)
#       5 #print(score['rouge3'].mid)
#
# /usr/local/lib/python3.7/dist-packages/datasets/metric.py in compute(self, predictions, references, **kwargs)
#     390
#     391         Usage of positional arguments is not allowed to prevent mistakes.
# --> 392
#     393         Args:
#     394             predictions (list/array/tensor, optional): Predictions.
#
# /usr/local/lib/python3.7/dist-packages/datasets/metric.py in add_batch(self, predictions, references)
#     442                 del self.data
# ...
